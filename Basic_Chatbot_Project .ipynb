# %%
print("Welcome to Horizon TechX Chatbot!")

while True:
    user = input("You: ").lower()

    if user == "hello":
        print("Bot: Hi! Nice to meet you.")

    elif user == "how are you":
        print("Bot: I am doing great!")

    elif user == "what is your name":
        print("Bot: I am Horizon Bot.")

    elif user == "help":
        print("Bot: You can say hello, bye, or ask my name.")

    elif user == "bye":
        print("Bot: Goodbye! Have a nice day.")
        break

    else:
        print("Bot: Sorry, I don't understand.")
# Out:
# Welcome to Horizon TechX Chatbot!
# You:  hi
# Bot: Sorry, I don't understand.
# You:  hello
# Bot: Hi! Nice to meet you.
